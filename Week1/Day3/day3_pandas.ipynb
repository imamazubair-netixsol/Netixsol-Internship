# %%
import pandas as pd

# %%
df = pd.read_csv("pakistan_economic_indicators_2000_2025.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 32 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    26 non-null     int64
#  1   gdp_usd_bn              26 non-null     float64
#  2   gdp_growth_pct          26 non-null     float64
#  3   gdp_per_capita_usd      26 non-null     int64
#  4   inflation_cpi_pct       26 non-null     float64
#  5   unemployment_pct        26 non-null     float64
#  6   remittances_usd_bn      26 non-null     float64
#  7   exports_usd_bn          26 non-null     float64
#  8   imports_usd_bn          26 non-null     float64
#  9   trade_balance_usd_bn    26 non-null     float64
#  10  forex_reserves_usd_bn   26 non-null     float64
#  11  policy_rate_pct         26 non-null     float64
#  12  pkr_per_usd             26 non-null     float64
#  13  public_debt_gdp_pct     26 non-null     float64
# ...

# %%
df.shape
# Out:
# (26, 32)

# %%
df.isna().sum()
# Out:
# year                      0
# gdp_usd_bn                0
# gdp_growth_pct            0
# gdp_per_capita_usd        0
# inflation_cpi_pct         0
# unemployment_pct          0
# remittances_usd_bn        0
# exports_usd_bn            0
# imports_usd_bn            0
# trade_balance_usd_bn      0
# forex_reserves_usd_bn     0
# policy_rate_pct           0
# pkr_per_usd               0
# public_debt_gdp_pct       0
# current_account_usd_bn    0
# fdi_inflows_usd_bn        0
# population_mn             0
# literacy_rate_pct         0
# agriculture_gdp_pct       0
# services_gdp_pct          0
# industry_gdp_pct          0
# tax_revenue_gdp_pct       0
# mobile_per_100            0
# imf_program_active        0
# key_events                0
# remittances_gdp_pct       0
# exports_gdp_pct           0
# imports_gdp_pct           0
# fdi_gdp_pct               0
# gdp_growth_category       0
# inflation_category        0
# decade                    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# year                      0
# gdp_usd_bn                0
# gdp_growth_pct            0
# gdp_per_capita_usd        0
# inflation_cpi_pct         0
# unemployment_pct          0
# remittances_usd_bn        0
# exports_usd_bn            0
# imports_usd_bn            0
# trade_balance_usd_bn      0
# forex_reserves_usd_bn     0
# policy_rate_pct           0
# pkr_per_usd               0
# public_debt_gdp_pct       0
# current_account_usd_bn    0
# fdi_inflows_usd_bn        0
# population_mn             0
# literacy_rate_pct         0
# agriculture_gdp_pct       0
# services_gdp_pct          0
# industry_gdp_pct          0
# tax_revenue_gdp_pct       0
# mobile_per_100            0
# imf_program_active        0
# key_events                0
# remittances_gdp_pct       0
# exports_gdp_pct           0
# imports_gdp_pct           0
# fdi_gdp_pct               0
# gdp_growth_category       0
# inflation_category        0
# decade                    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['year', 'gdp_usd_bn', 'gdp_growth_pct', 'gdp_per_capita_usd',
#        'inflation_cpi_pct', 'unemployment_pct', 'remittances_usd_bn',
#        'exports_usd_bn', 'imports_usd_bn', 'trade_balance_usd_bn',
#        'forex_reserves_usd_bn', 'policy_rate_pct', 'pkr_per_usd',
#        'public_debt_gdp_pct', 'current_account_usd_bn', 'fdi_inflows_usd_bn',
#        'population_mn', 'literacy_rate_pct', 'agriculture_gdp_pct',
#        'services_gdp_pct', 'industry_gdp_pct', 'tax_revenue_gdp_pct',
#        'mobile_per_100', 'imf_program_active', 'key_events',
#        'remittances_gdp_pct', 'exports_gdp_pct', 'imports_gdp_pct',
#        'fdi_gdp_pct', 'gdp_growth_category', 'inflation_category', 'decade'],
#       dtype='str')

# %%
df.dtypes
# Out:
# year                        int64
# gdp_usd_bn                float64
# gdp_growth_pct            float64
# gdp_per_capita_usd          int64
# inflation_cpi_pct         float64
# unemployment_pct          float64
# remittances_usd_bn        float64
# exports_usd_bn            float64
# imports_usd_bn            float64
# trade_balance_usd_bn      float64
# forex_reserves_usd_bn     float64
# policy_rate_pct           float64
# pkr_per_usd               float64
# public_debt_gdp_pct       float64
# current_account_usd_bn    float64
# fdi_inflows_usd_bn        float64
# population_mn             float64
# literacy_rate_pct         float64
# agriculture_gdp_pct       float64
# services_gdp_pct          float64
# industry_gdp_pct          float64
# tax_revenue_gdp_pct       float64
# mobile_per_100            float64
# imf_program_active          int64
# key_events                    str
# remittances_gdp_pct       float64
# exports_gdp_pct           float64
# ...

# %%
df.describe()
# Out:
#               year  gdp_usd_bn  gdp_growth_pct  gdp_per_capita_usd  \
# count    26.000000   26.000000       26.000000           26.000000
# mean   2012.500000  233.084615        4.110000         1012.153846
# std       7.648529   92.279119        2.195969          258.434161
# min    2000.000000   99.900000       -0.500000          614.000000
# 25%    2006.250000  156.300000        2.700000          807.000000
# 50%    2012.500000  243.350000        4.100000         1040.500000
# 75%    2018.750000  299.375000        5.650000         1226.000000
# max    2025.000000  390.000000        9.000000         1393.000000
#
#        inflation_cpi_pct  unemployment_pct  remittances_usd_bn  \
# count          26.000000         26.000000           26.000000
# mean            9.361538          6.261538           14.866538
# std             6.431739          1.059085           10.775681
# min             2.900000          4.500000            1.080000
# ...

# %%
df2 = pd.read_csv("pakistan_economic_indicators_2000_2025.csv")

# %%
df2.isna().sum()
# Out:
# year                      0
# gdp_usd_bn                0
# gdp_growth_pct            0
# gdp_per_capita_usd        0
# inflation_cpi_pct         0
# unemployment_pct          0
# remittances_usd_bn        0
# exports_usd_bn            0
# imports_usd_bn            0
# trade_balance_usd_bn      0
# forex_reserves_usd_bn     0
# policy_rate_pct           0
# pkr_per_usd               0
# public_debt_gdp_pct       0
# current_account_usd_bn    0
# fdi_inflows_usd_bn        0
# population_mn             0
# literacy_rate_pct         0
# agriculture_gdp_pct       0
# services_gdp_pct          0
# industry_gdp_pct          0
# tax_revenue_gdp_pct       0
# mobile_per_100            0
# imf_program_active        0
# key_events                0
# remittances_gdp_pct       0
# exports_gdp_pct           0
# imports_gdp_pct           0
# fdi_gdp_pct               0
# gdp_growth_category       0
# inflation_category        0
# decade                    0
# dtype: int64

# %% [markdown]
# # Certain Business Questions that can be answered

# %% [markdown]
# ### 1. Year with the highest GDP (according to )

# %%
df["year"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df["year"].iloc[40]
#
# File d:\Python311\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\Python311\Lib\site-packages\pandas\core\indexing.py:1773, in _iLocIndexer._getitem_axis(self, key, axis)
#    1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# -> 1773 self._validate_integer(key, axis)
#    1775 return self.obj._ixs(key, axis=axis)
#
# File d:\Python311\Lib\site-packages\pandas\core\indexing.py:1706, in _iLocIndexer._validate_integer(self, key, axis)
# ...
