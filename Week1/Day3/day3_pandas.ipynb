# %%
import kagglehub
# Download latest version
path = kagglehub.dataset_download("karkavelrajaj/amazon-sales-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\imama\.cache\kagglehub\datasets\karkavelrajaj\amazon-sales-dataset\versions\1

# %%
import pandas as pd
from kagglehub import KaggleDatasetAdapter

# %%
df = kagglehub.dataset_load(KaggleDatasetAdapter.PANDAS,
    "karkavelrajaj/amazon-sales-dataset",
    "amazon.csv")

print(df.head())
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File d:\Python311\Lib\site-packages\kagglehub\pandas_datasets.py:92, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      91 try:
# ---> 92     result = read_function(
#      93         *_build_args(read_function, filepath, sql_query),
#      94         **_build_kwargs(file_extension, pandas_kwargs),
#      95     )
#      96 except Exception as e:
#
# File d:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File d:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#
# File d:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File d:\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#
# File d:\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#
# File pandas/_libs/parsers.pyx:568, in pandas._libs.parsers.TextReader.__cinit__()
# --> 568 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:657, in pandas._libs.parsers.TextReader._get_header()
# --> 657 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:868, in pandas._libs.parsers.TextReader._tokenize_rows()
# --> 868 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:885, in pandas._libs.parsers.TextReader._check_tokenize_status()
# --> 885 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/parsers.pyx:2076, in pandas._libs.parsers.raise_parser_error()
# -> 2076 'Could not get source, probably due dynamically evaluated source code.'
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa8 in position 10: invalid start byte
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df = kagglehub.dataset_load(KaggleDatasetAdapter.PANDAS,
#       2     "karkavelrajaj/amazon-sales-dataset",
#       3     "amazon.csv")
#       4
#
# File d:\Python311\Lib\site-packages\kagglehub\datasets.py:155, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     152 elif adapter is KaggleDatasetAdapter.PANDAS:
#     153     import kagglehub.pandas_datasets  # noqa: PLC0415
# --> 155     return kagglehub.pandas_datasets.load_pandas_dataset(
#     156         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     157     )
#     158 elif adapter is KaggleDatasetAdapter.POLARS:
#     159     import kagglehub.polars_datasets  # noqa: PLC0415
#
# File d:\Python311\Lib\site-packages\kagglehub\pandas_datasets.py:98, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      96 except Exception as e:
#      97     read_error_message = f"Error reading file: {e}"
# ---> 98     raise ValueError(read_error_message) from e
#     100 return result
#
# ValueError: Error reading file: 'utf-8' codec can't decode byte 0xa8 in position 10: invalid start byte
